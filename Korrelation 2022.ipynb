# %% [markdown]
# # Datentypen Verarbeitung - Datei 2022

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
# Aktuelle Pfade
file_paths = [
    "/Users/andreaheigl/Documents/BA/data/rad_2022_tage_19_06_23_r.csv",
    "/Users/andreaheigl/Documents/BA/data/rad_2021_tage_19_06_23_r.csv",
    "/Users/andreaheigl/Documents/BA/data/rad_2020_tage_19_06_23_r.csv",
    "/Users/andreaheigl/Documents/BA/data/rad_2019_tage_19_06_23_r.csv",
    "/Users/andreaheigl/Documents/BA/data/rad_2018_tage_19_06_23_r.csv",
    "/Users/andreaheigl/Documents/BA/data/rad_2017_tage_19_06_23_r.csv",
    "/Users/andreaheigl/Documents/BA/data/rad_2016_tage_19_06_23_r.csv",
    "/Users/andreaheigl/Documents/BA/data/rad_2015_tage_19_06_23_r.csv",
    "/Users/andreaheigl/Documents/BA/data/rad_2014_tage_19_06_23_r.csv",
    "/Users/andreaheigl/Documents/BA/data/rad_2013_tage_19_06_23_r.csv",
    "/Users/andreaheigl/Documents/BA/data/rad_2012_tage_19_06_23_r.csv",
#    "/Users/andreaheigl/Documents/BA/data/rad_2011_tage_19_06_23_r.csv",
#    "/Users/andreaheigl/Documents/BA/data/rad_2010_tage_19_06_23_r.csv",
#    "/Users/andreaheigl/Documents/BA/data/rad_2009_tage_19_06_23_r.csv",
#    "/Users/andreaheigl/Documents/BA/data/rad_2008_tage_19_06_23_r.csv"
]

# 24077 rows × 13 columns

# %%
df = pd.read_csv("/Users/andreaheigl/Documents/BA/data/rad_2017_tage_19_06_23_r.csv")

# %%
# Ersten 5 Zeilen anzeigen
df.head()
# Out:
#         datum zaehlstelle uhrzeit_start uhrzeit_ende  richtung_1  richtung_2  \
# 0  2017-01-01      Arnulf         00:00        23:59         121          14
# 1  2017-01-02      Arnulf         00:00        23:59         362          38
# 2  2017-01-03      Arnulf         00:00        23:59         232          30
# 3  2017-01-04      Arnulf         00:00        23:59         182          25
# 4  2017-01-05      Arnulf         00:00        23:59         193          31
#
#    gesamt  min.temp  max.temp  niederschlag  bewoelkung  sonnenstunden  \
# 0     135      -6.1       2.6           0.0          36            5.9
# 1     400      -5.4       0.8           3.2          69            0.3
# 2     262      -2.1       0.6           0.0          85            3.6
# 3     207      -0.9       1.3           2.2          94            0.0
# 4     224      -7.1      -0.2           0.0          88            0.0
#
#    kommentar
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %% [markdown]
# #### Für Bildung von Korrelationen brauchen wir die Datentypen:
# Include only float, int or boolean data.

# %%
# Datentypen ausgeben
df.dtypes
# Out:
# datum             object
# uhrzeit_start     object
# uhrzeit_ende     float64
# zaehlstelle       object
# richtung_1         int64
# richtung_2         int64
# gesamt             int64
# min.temp          object
# max.temp          object
# niederschlag      object
# bewoelkung         int64
# sonnenstunden     object
# dtype: object

# %%
df = df.drop(columns=['uhrzeit_ende'], errors='ignore')
# errors='ignore': nicht vorhandene Spalten werden ignoriert beim Löschen

# %%
df
# Out:
#            datum zaehlstelle uhrzeit_start  richtung_1  richtung_2  gesamt  \
# 0     2017-01-01      Arnulf         00:00         121          14     135
# 1     2017-01-02      Arnulf         00:00         362          38     400
# 2     2017-01-03      Arnulf         00:00         232          30     262
# 3     2017-01-04      Arnulf         00:00         182          25     207
# 4     2017-01-05      Arnulf         00:00         193          31     224
# ...          ...         ...           ...         ...         ...     ...
# 2185  2017-12-27     Olympia         00:00         173         161     334
# 2186  2017-12-28     Olympia         00:00         108          85     193
# 2187  2017-12-29     Olympia         00:00         119         113     232
# 2188  2017-12-30     Olympia         00:00          91          73     164
# 2189  2017-12-31     Olympia         00:00         367         274     641
#
#       min.temp  max.temp  niederschlag  bewoelkung  sonnenstunden  kommentar
# 0         -6.1       2.6           0.0          36            5.9        NaN
# 1         -5.4       0.8           3.2          69            0.3        NaN
# 2         -2.1       0.6           0.0          85            3.6        NaN
# 3         -0.9       1.3           2.2          94            0.0        NaN
# 4         -7.1      -0.2           0.0          88            0.0        NaN
# ...        ...       ...           ...         ...            ...        ...
# 2185      -1.6       2.6           7.3          94            0.7        NaN
# 2186      -1.0       1.5           5.5          96            0.0        NaN
# 2187      -2.0       2.2           1.8          73            6.5        NaN
# 2188       2.0      10.5           4.4          98            0.0        NaN
# 2189       3.5      13.5           0.7          73            6.6        NaN
#
# [2190 rows x 12 columns]

# %% [markdown]
# # ACHTUNG: Werte werden gelöscht

# %%
# Entferne NaN-Werte (optional)
df = df.dropna()

# Entferne 0-Werte (optional)
df = df.replace(0, np.nan).dropna()

# %%
df
# Out:
#            datum uhrzeit_start zaehlstelle  richtung_1  richtung_2  gesamt  \
# 0     2022-01-01         00:00      Arnulf         444           0     444
# 1     2022-01-02         00:00      Arnulf         476           0     476
# 2     2022-01-03         00:00      Arnulf         752           0     752
# 3     2022-01-04         00:00      Arnulf         603           0     603
# 4     2022-01-05         00:00      Arnulf         578           0     578
# ...          ...           ...         ...         ...         ...     ...
# 2185  2022-12-27         00:00     Erhardt         809         698    1507
# 2186  2022-12-28         00:00     Erhardt         934         855    1789
# 2187  2022-12-29         00:00     Erhardt        1087        1006    2093
# 2188  2022-12-30         00:00     Erhardt        1115         996    2111
# 2189  2022-12-31         00:00     Erhardt         950         918    1868
#
#       min.temp  max.temp  niederschlag  bewoelkung  sonnenstunden
# 0          3.2      13.4           0.0          68            7.6
# 1          1.9      15.8           0.0          80            4.7
# 2          8.7      11.5           0.7          99            0.0
# 3          3.7      16.5          10.3          98            1.0
# 4          0.3       3.9           1.2          95            0.4
# ...        ...       ...           ...         ...            ...
# 2185       1.2       7.0           0.0          64            5.6
# 2186       0.6       9.5           0.0          93            3.6
# 2187       5.1      13.5           1.2          98            3.4
# 2188       4.3      12.7           1.5          76            6.1
# 2189      10.5      20.0           0.0          96            2.9
#
# [2190 rows x 11 columns]

# %% [markdown]
# # Korrelationsmatrix ohne Skalierung bilden

# %%
corr_matrix = df.corr(numeric_only=True)
# numeric_only=True: nur die Spalten mit numerischen Werten werden berücksichtigt

# %%
corr_matrix
# Out:
#                richtung_1  richtung_2    gesamt  min.temp  max.temp  \
# richtung_1       1.000000    0.884642  0.970215  0.333143  0.431266
# richtung_2       0.884642    1.000000  0.971245  0.222585  0.305908
# gesamt           0.970215    0.971245  1.000000  0.285748  0.379139
# min.temp         0.333143    0.222585  0.285748  1.000000  0.906928
# max.temp         0.431266    0.305908  0.379139  0.906928  1.000000
# niederschlag    -0.038403   -0.034778 -0.037677  0.259351  0.201734
# bewoelkung      -0.235883   -0.183416 -0.215735 -0.153037 -0.363342
# sonnenstunden    0.405280    0.310451  0.368231  0.369696  0.634288
#
#                niederschlag  bewoelkung  sonnenstunden
# richtung_1        -0.038403   -0.235883       0.405280
# richtung_2        -0.034778   -0.183416       0.310451
# gesamt            -0.037677   -0.215735       0.368231
# min.temp           0.259351   -0.153037       0.369696
# max.temp           0.201734   -0.363342       0.634288
# niederschlag       1.000000    0.071198      -0.046795
# bewoelkung         0.071198    1.000000      -0.758714
# sonnenstunden     -0.046795   -0.758714       1.000000

# %%
corr_matrix.dtypes
# Out:
# richtung_1       float64
# richtung_2       float64
# gesamt           float64
# min.temp         float64
# max.temp         float64
# niederschlag     float64
# bewoelkung       float64
# sonnenstunden    float64
# dtype: object

# %% [markdown]
# # Korrelationsmatrix mit Skalierung bilden

# %% [markdown]
# ## Korrelationsmatrix bilden mit auch nicht numerischen Werten

# %%
# Initialisiere den StandardScaler
scaler = StandardScaler()

# Wende den StandardScaler auf das DataFrame an
scaled_data = scaler.fit_transform(corr_matrix)

# Erstelle ein neues DataFrame mit skalierten Werten
df_scaled = pd.DataFrame(scaled_data, columns=corr_matrix.columns)

# Berechne die Korrelationsmatrix für die skalierten Daten
correlation_matrix_scaled = df_scaled.corr()

# Korrelationsmatrix anzeigen
correlation_matrix_scaled
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       2 scaler = StandardScaler()
#       4 # Wende den StandardScaler auf das DataFrame an
# ----> 5 scaled_data = scaler.fit_transform(corr_matrix)
#       7 # Erstelle ein neues DataFrame mit skalierten Werten
#       8 df_scaled = pd.DataFrame(scaled_data, columns=corr_matrix.columns)
#
# NameError: name 'corr_matrix' is not defined

# %% [markdown]
# ## Korrelationsmatrix bilden mit nur numerischen Werten

# %%
# Wähle nur numerische Spalten aus
numeric_columns = df.select_dtypes(include='number')

# Initialisiere den StandardScaler
scaler = StandardScaler()

# Wende den StandardScaler auf die ausgewählten numerischen Spalten an
scaled_data = scaler.fit_transform(numeric_columns)

# Erstelle ein neues DataFrame mit skalierten Werten
df_scaled = pd.DataFrame(scaled_data, columns=numeric_columns.columns)

# Berechne die Korrelationsmatrix für die skalierten Daten
correlation_matrix_scaled = df_scaled.corr()

# Korrelationsmatrix anzeigen
correlation_matrix_scaled
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#                richtung_1  richtung_2    gesamt  min.temp  max.temp  \
# richtung_1       1.000000    0.858818  0.964462  0.466198  0.543335
# richtung_2       0.858818    1.000000  0.963653  0.388448  0.452847
# gesamt           0.964462    0.963653  1.000000  0.443476  0.516919
# min.temp         0.466198    0.388448  0.443476  1.000000  0.902684
# max.temp         0.543335    0.452847  0.516919  0.902684  1.000000
# niederschlag    -0.130109   -0.106925 -0.123002  0.105730  0.013172
# bewoelkung      -0.286385   -0.240414 -0.273350 -0.039767 -0.368480
# sonnenstunden    0.451768    0.376239  0.429654  0.340851  0.636136
# kommentar             NaN         NaN       NaN       NaN       NaN
#
#                niederschlag  bewoelkung  sonnenstunden  kommentar
# richtung_1        -0.130109   -0.286385       0.451768        NaN
# richtung_2        -0.106925   -0.240414       0.376239        NaN
# gesamt            -0.123002   -0.273350       0.429654        NaN
# min.temp           0.105730   -0.039767       0.340851        NaN
# max.temp           0.013172   -0.368480       0.636136        NaN
# niederschlag       1.000000    0.271949      -0.279259        NaN
# bewoelkung         0.271949    1.000000      -0.847337        NaN
# sonnenstunden     -0.279259   -0.847337       1.000000        NaN
# kommentar               NaN         NaN            NaN        NaN

# %% [markdown]
# # Korrelationsmatrix visualisieren

# %%
# Plot der Korrelationsmatrix mit Seaborn
sns.set(style="white")
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix_scaled, annot=True, cmap="coolwarm", fmt=".2f")

# Hinzufügen des Titels
plt.title("Korrelationsmatrix 2017")

# Diagramm anzeigen
plt.show()

# %%
# Speichern des Plots als PNG-Datei
plt.savefig('korrelationsmatrix_2017.png')

# %% [markdown]
# # Korrelation in Scatterplot visualisieren

# %%
sns.scatterplot(data=df, x="gesamt", y="niederschlag")
